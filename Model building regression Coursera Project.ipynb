# %%
# start with pandas and numpy

# %%
import pandas as pd
import numpy as np

# %%
# import the data set
data1 =  pd.read_csv("C:\\Users\\Manohar Kapse\\PyCaret\\Pycaret Self Video\\1. Session\\happiness_report revised.csv")

# %%
data1.head()
# Out:
#    SNO Country or region  Happyness_Score  GDP per capita  Social support  \
# 0    1           Finland            7.769           1.340           1.587
# 1    2           Denmark            7.600             NaN           1.573
# 2    3            Norway            7.554           1.488             NaN
# 3    4           Iceland            7.494           1.380           1.624
# 4    5       Netherlands            7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                      NaN                         0.591       0.354
# 4                    0.999                           NaN       0.322
#
#    Perceptions of corruption                 Region Income group  \
# 0                      0.393  Europe & Central Asia  High income
# 1                      0.410  Europe & Central Asia  High income
# 2                      0.341  Europe & Central Asia  High income
# 3                      0.118  Europe & Central Asia  High income
# 4                      0.298  Europe & Central Asia  High income
#
#   Happiness_Group
# 0      high_score
# 1      high_score
# 2      high_score
# 3      high_score
# 4      high_score

# %%
from pycaret import *

# %%
### https://pycaret.gitbook.io/docs/

# %%
from pycaret.regression import *

# %%
# start regression with 
# RegressionExperiment
reg_exp = RegressionExperiment()

# %%
# Basic setup
# Step 1
reg_exp1 = reg_exp.setup(data=data1, target="Happyness_Score",
                        numeric_features=["GDP per capita",
                                          "Social support",
                                          "Healthy life expectancy",
                                          "Freedom to make life choices",
                                          "Generosity",
                                          "Perceptions of corruption"],
                         ignore_features=["SNO",
                                          "Country or region",
                                          "Happiness_Group",
                                          "Region",
                                          "Income group"])
# Out:
# <style type="text/css">
# #T_20a16_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_20a16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20a16_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_20a16_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20a16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20a16_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_20a16_row0_col1" class="data row0 col1" >5559</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20a16_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_20a16_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20a16_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_20a16_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20a16_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_20a16_row3_col1" class="data row3 col1" >(156, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20a16_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_20a16_row4_col1" class="data row4 col1" >(156, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20a16_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_20a16_row5_col1" class="data row5 col1" >(109, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20a16_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_20a16_row6_col1" class="data row6 col1" >(47, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20a16_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_20a16_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20a16_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_20a16_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20a16_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_20a16_row9_col1" class="data row9 col1" >6.4%</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_20a16_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_20a16_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_20a16_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_20a16_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_20a16_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_20a16_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_20a16_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_20a16_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_20a16_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_20a16_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_20a16_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_20a16_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_20a16_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_20a16_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_20a16_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_20a16_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_20a16_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_20a16_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_20a16_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_20a16_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_20a16_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_20a16_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_20a16_row20_col1" class="data row20 col1" >f6fa</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create a specific model, say linear regression
regression1 = reg_exp1.create_model('lr')
# Out:
# <style type="text/css">
# #T_057c9_row10_col0, #T_057c9_row10_col1, #T_057c9_row10_col2, #T_057c9_row10_col3, #T_057c9_row10_col4, #T_057c9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_057c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_057c9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_057c9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_057c9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_057c9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_057c9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_057c9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_057c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_057c9_row0_col0" class="data row0 col0" >0.4212</td>
#       <td id="T_057c9_row0_col1" class="data row0 col1" >0.2469</td>
#       <td id="T_057c9_row0_col2" class="data row0 col2" >0.4969</td>
#       <td id="T_057c9_row0_col3" class="data row0 col3" >0.5153</td>
#       <td id="T_057c9_row0_col4" class="data row0 col4" >0.0668</td>
#       <td id="T_057c9_row0_col5" class="data row0 col5" >0.0657</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_057c9_row1_col0" class="data row1 col0" >0.4342</td>
#       <td id="T_057c9_row1_col1" class="data row1 col1" >0.2531</td>
#       <td id="T_057c9_row1_col2" class="data row1 col2" >0.5031</td>
#       <td id="T_057c9_row1_col3" class="data row1 col3" >0.8841</td>
#       <td id="T_057c9_row1_col4" class="data row1 col4" >0.0906</td>
#       <td id="T_057c9_row1_col5" class="data row1 col5" >0.0983</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_057c9_row2_col0" class="data row2 col0" >0.4896</td>
#       <td id="T_057c9_row2_col1" class="data row2 col1" >0.4378</td>
#       <td id="T_057c9_row2_col2" class="data row2 col2" >0.6617</td>
#       <td id="T_057c9_row2_col3" class="data row2 col3" >0.5001</td>
#       <td id="T_057c9_row2_col4" class="data row2 col4" >0.1229</td>
#       <td id="T_057c9_row2_col5" class="data row2 col5" >0.1128</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_057c9_row3_col0" class="data row3 col0" >0.4033</td>
#       <td id="T_057c9_row3_col1" class="data row3 col1" >0.2219</td>
#       <td id="T_057c9_row3_col2" class="data row3 col2" >0.4711</td>
#       <td id="T_057c9_row3_col3" class="data row3 col3" >0.5802</td>
#       <td id="T_057c9_row3_col4" class="data row3 col4" >0.0769</td>
#       <td id="T_057c9_row3_col5" class="data row3 col5" >0.0758</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_057c9_row4_col0" class="data row4 col0" >0.6431</td>
#       <td id="T_057c9_row4_col1" class="data row4 col1" >0.5745</td>
#       <td id="T_057c9_row4_col2" class="data row4 col2" >0.7580</td>
#       <td id="T_057c9_row4_col3" class="data row4 col3" >0.6744</td>
#       <td id="T_057c9_row4_col4" class="data row4 col4" >0.1271</td>
#       <td id="T_057c9_row4_col5" class="data row4 col5" >0.1317</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_057c9_row5_col0" class="data row5 col0" >0.3694</td>
#       <td id="T_057c9_row5_col1" class="data row5 col1" >0.2049</td>
#       <td id="T_057c9_row5_col2" class="data row5 col2" >0.4526</td>
#       <td id="T_057c9_row5_col3" class="data row5 col3" >0.2762</td>
#       <td id="T_057c9_row5_col4" class="data row5 col4" >0.0729</td>
#       <td id="T_057c9_row5_col5" class="data row5 col5" >0.0687</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_057c9_row6_col0" class="data row6 col0" >0.4054</td>
#       <td id="T_057c9_row6_col1" class="data row6 col1" >0.2280</td>
#       <td id="T_057c9_row6_col2" class="data row6 col2" >0.4775</td>
#       <td id="T_057c9_row6_col3" class="data row6 col3" >0.8332</td>
#       <td id="T_057c9_row6_col4" class="data row6 col4" >0.0724</td>
#       <td id="T_057c9_row6_col5" class="data row6 col5" >0.0758</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_057c9_row7_col0" class="data row7 col0" >0.4500</td>
#       <td id="T_057c9_row7_col1" class="data row7 col1" >0.3160</td>
#       <td id="T_057c9_row7_col2" class="data row7 col2" >0.5621</td>
#       <td id="T_057c9_row7_col3" class="data row7 col3" >0.2713</td>
#       <td id="T_057c9_row7_col4" class="data row7 col4" >0.1000</td>
#       <td id="T_057c9_row7_col5" class="data row7 col5" >0.0851</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_057c9_row8_col0" class="data row8 col0" >0.4684</td>
#       <td id="T_057c9_row8_col1" class="data row8 col1" >0.3765</td>
#       <td id="T_057c9_row8_col2" class="data row8 col2" >0.6136</td>
#       <td id="T_057c9_row8_col3" class="data row8 col3" >0.6890</td>
#       <td id="T_057c9_row8_col4" class="data row8 col4" >0.0943</td>
#       <td id="T_057c9_row8_col5" class="data row8 col5" >0.0937</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_057c9_row9_col0" class="data row9 col0" >0.3920</td>
#       <td id="T_057c9_row9_col1" class="data row9 col1" >0.2021</td>
#       <td id="T_057c9_row9_col2" class="data row9 col2" >0.4496</td>
#       <td id="T_057c9_row9_col3" class="data row9 col3" >0.8023</td>
#       <td id="T_057c9_row9_col4" class="data row9 col4" >0.0821</td>
#       <td id="T_057c9_row9_col5" class="data row9 col5" >0.0865</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_057c9_row10_col0" class="data row10 col0" >0.4476</td>
#       <td id="T_057c9_row10_col1" class="data row10 col1" >0.3062</td>
#       <td id="T_057c9_row10_col2" class="data row10 col2" >0.5446</td>
#       <td id="T_057c9_row10_col3" class="data row10 col3" >0.6026</td>
#       <td id="T_057c9_row10_col4" class="data row10 col4" >0.0906</td>
#       <td id="T_057c9_row10_col5" class="data row10 col5" >0.0894</td>
#     </tr>
#     <tr>
#       <th id="T_057c9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_057c9_row11_col0" class="data row11 col0" >0.0737</td>
#       <td id="T_057c9_row11_col1" class="data row11 col1" >0.1162</td>
#       <td id="T_057c9_row11_col2" class="data row11 col2" >0.0978</td>
#       <td id="T_057c9_row11_col3" class="data row11 col3" >0.2049</td>
#       <td id="T_057c9_row11_col4" class="data row11 col4" >0.0199</td>
#       <td id="T_057c9_row11_col5" class="data row11 col5" >0.0196</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Study the output of the model
regression1.coef_
# Out:
# array([0.7279073, 1.1697228, 1.1377565, 1.2502377, 2.0387127, 0.5121567],
#       dtype=float32)

# %%
regression1.feature_names_in_
# Out:
# array(['GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'], dtype=object)

# %%
# Evaluate the model

# %%
reg_exp1.evaluate_model(regression1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Topics Covered
    # interactive residual
    # heteroscadisticty: resiudual vs predicted
    # normality of residual {if wethink there is problem with residual analysis, 
    # use transformation or outliers}
    # cooks distance: use outlier detection methods
    # learning curve
    # Validation Curve # hyperparameters
    # manifold learning problem is unsupervised: 
    # it learns the high-dimensional structure of the data from the data itself, 
    # without the use of predetermined classifications.

# %%
reg_exp1.X_test.corr() # using correlation we can try to find multicollinearity
# Out:
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.742332
# Social support                      0.742332        1.000000
# Healthy life expectancy             0.827079        0.761794
# Freedom to make life choices        0.437245        0.585526
# Generosity                         -0.064804       -0.068176
# Perceptions of corruption           0.357357        0.329678
#
#                               Healthy life expectancy  \
# GDP per capita                               0.827079
# Social support                               0.761794
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.434591
# Generosity                                  -0.011656
# Perceptions of corruption                    0.285707
#
#                               Freedom to make life choices  Generosity  \
# GDP per capita                                    0.437245   -0.064804
# Social support                                    0.585526   -0.068176
# Healthy life expectancy                           0.434591   -0.011656
# Freedom to make life choices                      1.000000    0.290887
# Generosity                                        0.290887    1.000000
# Perceptions of corruption                         0.416738    0.265490
#
#                               Perceptions of corruption
# GDP per capita                                 0.357357
# Social support                                 0.329678
# Healthy life expectancy                        0.285707
# Freedom to make life choices                   0.416738
# Generosity                                     0.265490
# Perceptions of corruption                      1.000000

# %%
# multicollinearity
reg_exp2 = reg_exp.setup(data=data1, target="Happyness_Score",
                        numeric_features=["GDP per capita",
                                          "Social support",
                                          "Healthy life expectancy",
                                          "Freedom to make life choices",
                                          "Generosity",
                                          "Perceptions of corruption"],
                        #categorical_features=["Region","Income group"],
                        ignore_features=["SNO","Country or region","Happiness_Group","Region","Income group"],
                        remove_multicollinearity=True,
                        multicollinearity_threshold=0.3)
# create a specific model, say linear regression
regression2 = reg_exp2.create_model('lr')
# Out:
# <style type="text/css">
# #T_483eb_row10_col1, #T_483eb_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_483eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_483eb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_483eb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_483eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_483eb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_483eb_row0_col1" class="data row0 col1" >1253</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_483eb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_483eb_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_483eb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_483eb_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_483eb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_483eb_row3_col1" class="data row3 col1" >(156, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_483eb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_483eb_row4_col1" class="data row4 col1" >(156, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_483eb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_483eb_row5_col1" class="data row5 col1" >(109, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_483eb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_483eb_row6_col1" class="data row6 col1" >(47, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_483eb_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_483eb_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_483eb_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_483eb_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_483eb_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_483eb_row9_col1" class="data row9 col1" >6.4%</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_483eb_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_483eb_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_483eb_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_483eb_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_483eb_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_483eb_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_483eb_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_483eb_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_483eb_row14_col0" class="data row14 col0" >Remove multicollinearity</td>
#       <td id="T_483eb_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_483eb_row15_col0" class="data row15 col0" >Multicollinearity threshold</td>
#       <td id="T_483eb_row15_col1" class="data row15 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_483eb_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_483eb_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_483eb_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_483eb_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_483eb_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_483eb_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_483eb_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_483eb_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_483eb_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_483eb_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_483eb_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_483eb_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_483eb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_483eb_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_483eb_row22_col1" class="data row22 col1" >0f52</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6279f_row10_col0, #T_6279f_row10_col1, #T_6279f_row10_col2, #T_6279f_row10_col3, #T_6279f_row10_col4, #T_6279f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6279f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6279f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6279f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6279f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6279f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6279f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6279f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6279f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6279f_row0_col0" class="data row0 col0" >0.5088</td>
#       <td id="T_6279f_row0_col1" class="data row0 col1" >0.3385</td>
#       <td id="T_6279f_row0_col2" class="data row0 col2" >0.5818</td>
#       <td id="T_6279f_row0_col3" class="data row0 col3" >0.6741</td>
#       <td id="T_6279f_row0_col4" class="data row0 col4" >0.0847</td>
#       <td id="T_6279f_row0_col5" class="data row0 col5" >0.0898</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6279f_row1_col0" class="data row1 col0" >0.6140</td>
#       <td id="T_6279f_row1_col1" class="data row1 col1" >0.6402</td>
#       <td id="T_6279f_row1_col2" class="data row1 col2" >0.8001</td>
#       <td id="T_6279f_row1_col3" class="data row1 col3" >0.5644</td>
#       <td id="T_6279f_row1_col4" class="data row1 col4" >0.1761</td>
#       <td id="T_6279f_row1_col5" class="data row1 col5" >0.1440</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6279f_row2_col0" class="data row2 col0" >0.5523</td>
#       <td id="T_6279f_row2_col1" class="data row2 col1" >0.4274</td>
#       <td id="T_6279f_row2_col2" class="data row2 col2" >0.6537</td>
#       <td id="T_6279f_row2_col3" class="data row2 col3" >0.5449</td>
#       <td id="T_6279f_row2_col4" class="data row2 col4" >0.1101</td>
#       <td id="T_6279f_row2_col5" class="data row2 col5" >0.1165</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6279f_row3_col0" class="data row3 col0" >0.5026</td>
#       <td id="T_6279f_row3_col1" class="data row3 col1" >0.3886</td>
#       <td id="T_6279f_row3_col2" class="data row3 col2" >0.6234</td>
#       <td id="T_6279f_row3_col3" class="data row3 col3" >0.1608</td>
#       <td id="T_6279f_row3_col4" class="data row3 col4" >0.0981</td>
#       <td id="T_6279f_row3_col5" class="data row3 col5" >0.0977</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6279f_row4_col0" class="data row4 col0" >0.7765</td>
#       <td id="T_6279f_row4_col1" class="data row4 col1" >0.8291</td>
#       <td id="T_6279f_row4_col2" class="data row4 col2" >0.9105</td>
#       <td id="T_6279f_row4_col3" class="data row4 col3" >0.2592</td>
#       <td id="T_6279f_row4_col4" class="data row4 col4" >0.1363</td>
#       <td id="T_6279f_row4_col5" class="data row4 col5" >0.1440</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6279f_row5_col0" class="data row5 col0" >0.5790</td>
#       <td id="T_6279f_row5_col1" class="data row5 col1" >0.4586</td>
#       <td id="T_6279f_row5_col2" class="data row5 col2" >0.6772</td>
#       <td id="T_6279f_row5_col3" class="data row5 col3" >0.5367</td>
#       <td id="T_6279f_row5_col4" class="data row5 col4" >0.1151</td>
#       <td id="T_6279f_row5_col5" class="data row5 col5" >0.1143</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6279f_row6_col0" class="data row6 col0" >0.3725</td>
#       <td id="T_6279f_row6_col1" class="data row6 col1" >0.2214</td>
#       <td id="T_6279f_row6_col2" class="data row6 col2" >0.4705</td>
#       <td id="T_6279f_row6_col3" class="data row6 col3" >0.7818</td>
#       <td id="T_6279f_row6_col4" class="data row6 col4" >0.0752</td>
#       <td id="T_6279f_row6_col5" class="data row6 col5" >0.0724</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6279f_row7_col0" class="data row7 col0" >0.7889</td>
#       <td id="T_6279f_row7_col1" class="data row7 col1" >1.0211</td>
#       <td id="T_6279f_row7_col2" class="data row7 col2" >1.0105</td>
#       <td id="T_6279f_row7_col3" class="data row7 col3" >0.4295</td>
#       <td id="T_6279f_row7_col4" class="data row7 col4" >0.1498</td>
#       <td id="T_6279f_row7_col5" class="data row7 col5" >0.1366</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6279f_row8_col0" class="data row8 col0" >0.5332</td>
#       <td id="T_6279f_row8_col1" class="data row8 col1" >0.4655</td>
#       <td id="T_6279f_row8_col2" class="data row8 col2" >0.6823</td>
#       <td id="T_6279f_row8_col3" class="data row8 col3" >0.7505</td>
#       <td id="T_6279f_row8_col4" class="data row8 col4" >0.1088</td>
#       <td id="T_6279f_row8_col5" class="data row8 col5" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6279f_row9_col0" class="data row9 col0" >0.7446</td>
#       <td id="T_6279f_row9_col1" class="data row9 col1" >0.9127</td>
#       <td id="T_6279f_row9_col2" class="data row9 col2" >0.9554</td>
#       <td id="T_6279f_row9_col3" class="data row9 col3" >0.4213</td>
#       <td id="T_6279f_row9_col4" class="data row9 col4" >0.1623</td>
#       <td id="T_6279f_row9_col5" class="data row9 col5" >0.1617</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6279f_row10_col0" class="data row10 col0" >0.5972</td>
#       <td id="T_6279f_row10_col1" class="data row10 col1" >0.5703</td>
#       <td id="T_6279f_row10_col2" class="data row10 col2" >0.7365</td>
#       <td id="T_6279f_row10_col3" class="data row10 col3" >0.5123</td>
#       <td id="T_6279f_row10_col4" class="data row10 col4" >0.1216</td>
#       <td id="T_6279f_row10_col5" class="data row10 col5" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_6279f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6279f_row11_col0" class="data row11 col0" >0.1283</td>
#       <td id="T_6279f_row11_col1" class="data row11 col1" >0.2539</td>
#       <td id="T_6279f_row11_col2" class="data row11 col2" >0.1668</td>
#       <td id="T_6279f_row11_col3" class="data row11 col3" >0.1904</td>
#       <td id="T_6279f_row11_col4" class="data row11 col4" >0.0317</td>
#       <td id="T_6279f_row11_col5" class="data row11 col5" >0.0267</td>
#     </tr>
#   </tbody>
# </table>

# %%
reg_exp2.evaluate_model(regression2)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# outliers
reg_exp2 = reg_exp.setup(data=data1, target="Happyness_Score",
                        numeric_features=["GDP per capita",
                                          "Social support",
                                          "Healthy life expectancy",
                                          "Freedom to make life choices",
                                          "Generosity",
                                          "Perceptions of corruption"],
                        #categorical_features=["Region","Income group"],
                        ignore_features=["SNO","Country or region","Happiness_Group","Region","Income group"],
                        remove_multicollinearity=True,
                        multicollinearity_threshold=0.5, 
                         remove_outliers=True,
                        outliers_method='iforest')
# create a specific model, say linear regression
regression2 = reg_exp2.create_model('lr')
# Out:
# <style type="text/css">
# #T_d66f9_row10_col1, #T_d66f9_row14_col1, #T_d66f9_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d66f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d66f9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d66f9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d66f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d66f9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d66f9_row0_col1" class="data row0 col1" >7515</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d66f9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d66f9_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d66f9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d66f9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d66f9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d66f9_row3_col1" class="data row3 col1" >(156, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d66f9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d66f9_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d66f9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d66f9_row5_col1" class="data row5 col1" >(103, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d66f9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d66f9_row6_col1" class="data row6 col1" >(47, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d66f9_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_d66f9_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d66f9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d66f9_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d66f9_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_d66f9_row9_col1" class="data row9 col1" >6.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d66f9_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_d66f9_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d66f9_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_d66f9_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d66f9_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_d66f9_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d66f9_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_d66f9_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d66f9_row14_col0" class="data row14 col0" >Remove multicollinearity</td>
#       <td id="T_d66f9_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d66f9_row15_col0" class="data row15 col0" >Multicollinearity threshold</td>
#       <td id="T_d66f9_row15_col1" class="data row15 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d66f9_row16_col0" class="data row16 col0" >Remove outliers</td>
#       <td id="T_d66f9_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d66f9_row17_col0" class="data row17 col0" >Outliers threshold</td>
#       <td id="T_d66f9_row17_col1" class="data row17 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d66f9_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_d66f9_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d66f9_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_d66f9_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d66f9_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_d66f9_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d66f9_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_d66f9_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d66f9_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_d66f9_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d66f9_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_d66f9_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d66f9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d66f9_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_d66f9_row24_col1" class="data row24 col1" >e9cf</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2d4a1_row10_col0, #T_2d4a1_row10_col1, #T_2d4a1_row10_col2, #T_2d4a1_row10_col3, #T_2d4a1_row10_col4, #T_2d4a1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2d4a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d4a1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2d4a1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2d4a1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2d4a1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2d4a1_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2d4a1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d4a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d4a1_row0_col0" class="data row0 col0" >0.4693</td>
#       <td id="T_2d4a1_row0_col1" class="data row0 col1" >0.3428</td>
#       <td id="T_2d4a1_row0_col2" class="data row0 col2" >0.5855</td>
#       <td id="T_2d4a1_row0_col3" class="data row0 col3" >0.7557</td>
#       <td id="T_2d4a1_row0_col4" class="data row0 col4" >0.0978</td>
#       <td id="T_2d4a1_row0_col5" class="data row0 col5" >0.1003</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d4a1_row1_col0" class="data row1 col0" >0.5131</td>
#       <td id="T_2d4a1_row1_col1" class="data row1 col1" >0.3335</td>
#       <td id="T_2d4a1_row1_col2" class="data row1 col2" >0.5775</td>
#       <td id="T_2d4a1_row1_col3" class="data row1 col3" >0.4022</td>
#       <td id="T_2d4a1_row1_col4" class="data row1 col4" >0.0853</td>
#       <td id="T_2d4a1_row1_col5" class="data row1 col5" >0.0884</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d4a1_row2_col0" class="data row2 col0" >0.4184</td>
#       <td id="T_2d4a1_row2_col1" class="data row2 col1" >0.3440</td>
#       <td id="T_2d4a1_row2_col2" class="data row2 col2" >0.5865</td>
#       <td id="T_2d4a1_row2_col3" class="data row2 col3" >0.6246</td>
#       <td id="T_2d4a1_row2_col4" class="data row2 col4" >0.0880</td>
#       <td id="T_2d4a1_row2_col5" class="data row2 col5" >0.0826</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d4a1_row3_col0" class="data row3 col0" >0.5177</td>
#       <td id="T_2d4a1_row3_col1" class="data row3 col1" >0.4203</td>
#       <td id="T_2d4a1_row3_col2" class="data row3 col2" >0.6483</td>
#       <td id="T_2d4a1_row3_col3" class="data row3 col3" >0.5630</td>
#       <td id="T_2d4a1_row3_col4" class="data row3 col4" >0.1180</td>
#       <td id="T_2d4a1_row3_col5" class="data row3 col5" >0.1204</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d4a1_row4_col0" class="data row4 col0" >0.5193</td>
#       <td id="T_2d4a1_row4_col1" class="data row4 col1" >0.3438</td>
#       <td id="T_2d4a1_row4_col2" class="data row4 col2" >0.5864</td>
#       <td id="T_2d4a1_row4_col3" class="data row4 col3" >0.7800</td>
#       <td id="T_2d4a1_row4_col4" class="data row4 col4" >0.0883</td>
#       <td id="T_2d4a1_row4_col5" class="data row4 col5" >0.0897</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d4a1_row5_col0" class="data row5 col0" >0.2882</td>
#       <td id="T_2d4a1_row5_col1" class="data row5 col1" >0.1776</td>
#       <td id="T_2d4a1_row5_col2" class="data row5 col2" >0.4214</td>
#       <td id="T_2d4a1_row5_col3" class="data row5 col3" >0.8069</td>
#       <td id="T_2d4a1_row5_col4" class="data row5 col4" >0.0725</td>
#       <td id="T_2d4a1_row5_col5" class="data row5 col5" >0.0584</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d4a1_row6_col0" class="data row6 col0" >0.4614</td>
#       <td id="T_2d4a1_row6_col1" class="data row6 col1" >0.3141</td>
#       <td id="T_2d4a1_row6_col2" class="data row6 col2" >0.5605</td>
#       <td id="T_2d4a1_row6_col3" class="data row6 col3" >0.5930</td>
#       <td id="T_2d4a1_row6_col4" class="data row6 col4" >0.0801</td>
#       <td id="T_2d4a1_row6_col5" class="data row6 col5" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d4a1_row7_col0" class="data row7 col0" >0.5003</td>
#       <td id="T_2d4a1_row7_col1" class="data row7 col1" >0.3261</td>
#       <td id="T_2d4a1_row7_col2" class="data row7 col2" >0.5711</td>
#       <td id="T_2d4a1_row7_col3" class="data row7 col3" >0.5339</td>
#       <td id="T_2d4a1_row7_col4" class="data row7 col4" >0.0888</td>
#       <td id="T_2d4a1_row7_col5" class="data row7 col5" >0.0963</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2d4a1_row8_col0" class="data row8 col0" >0.5279</td>
#       <td id="T_2d4a1_row8_col1" class="data row8 col1" >0.3347</td>
#       <td id="T_2d4a1_row8_col2" class="data row8 col2" >0.5786</td>
#       <td id="T_2d4a1_row8_col3" class="data row8 col3" >0.7148</td>
#       <td id="T_2d4a1_row8_col4" class="data row8 col4" >0.0894</td>
#       <td id="T_2d4a1_row8_col5" class="data row8 col5" >0.0949</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2d4a1_row9_col0" class="data row9 col0" >0.5388</td>
#       <td id="T_2d4a1_row9_col1" class="data row9 col1" >0.4843</td>
#       <td id="T_2d4a1_row9_col2" class="data row9 col2" >0.6959</td>
#       <td id="T_2d4a1_row9_col3" class="data row9 col3" >0.7319</td>
#       <td id="T_2d4a1_row9_col4" class="data row9 col4" >0.1065</td>
#       <td id="T_2d4a1_row9_col5" class="data row9 col5" >0.1054</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2d4a1_row10_col0" class="data row10 col0" >0.4755</td>
#       <td id="T_2d4a1_row10_col1" class="data row10 col1" >0.3421</td>
#       <td id="T_2d4a1_row10_col2" class="data row10 col2" >0.5812</td>
#       <td id="T_2d4a1_row10_col3" class="data row10 col3" >0.6506</td>
#       <td id="T_2d4a1_row10_col4" class="data row10 col4" >0.0915</td>
#       <td id="T_2d4a1_row10_col5" class="data row10 col5" >0.0914</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2d4a1_row11_col0" class="data row11 col0" >0.0715</td>
#       <td id="T_2d4a1_row11_col1" class="data row11 col1" >0.0739</td>
#       <td id="T_2d4a1_row11_col2" class="data row11 col2" >0.0662</td>
#       <td id="T_2d4a1_row11_col3" class="data row11 col3" >0.1225</td>
#       <td id="T_2d4a1_row11_col4" class="data row11 col4" >0.0124</td>
#       <td id="T_2d4a1_row11_col5" class="data row11 col5" >0.0158</td>
#     </tr>
#   </tbody>
# </table>

# %%
#remove_outliers=True
#outliers_method=''

‘iforest’: Uses sklearn’s IsolationForest.
‘ee’: Uses sklearn’s EllipticEnvelope.
‘lof’: Uses sklearn’s LocalOutlierFactor.

# %%
# feature Selection
reg_exp2 = reg_exp.setup(data=data1, target="Happyness_Score",
                        numeric_features=["GDP per capita",
                                          "Social support",
                                          "Healthy life expectancy",
                                          "Freedom to make life choices",
                                          "Generosity",
                                          "Perceptions of corruption"],
                        #categorical_features=["Region","Income group"],
                        ignore_features=["SNO","Country or region","Happiness_Group","Region","Income group"],
                         feature_selection= True, feature_selection_method='univariate')
# create a specific model, say linear regression
regression2 = reg_exp2.create_model('lr')
# Out:
# <style type="text/css">
# #T_4364b_row10_col1, #T_4364b_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4364b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4364b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4364b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4364b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4364b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4364b_row0_col1" class="data row0 col1" >8502</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4364b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4364b_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4364b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4364b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4364b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4364b_row3_col1" class="data row3 col1" >(156, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4364b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4364b_row4_col1" class="data row4 col1" >(156, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4364b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4364b_row5_col1" class="data row5 col1" >(109, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4364b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4364b_row6_col1" class="data row6 col1" >(47, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4364b_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_4364b_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4364b_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4364b_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4364b_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_4364b_row9_col1" class="data row9 col1" >6.4%</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4364b_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_4364b_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4364b_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_4364b_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4364b_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_4364b_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4364b_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_4364b_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4364b_row14_col0" class="data row14 col0" >Feature selection</td>
#       <td id="T_4364b_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4364b_row15_col0" class="data row15 col0" >Feature selection method</td>
#       <td id="T_4364b_row15_col1" class="data row15 col1" >univariate</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4364b_row16_col0" class="data row16 col0" >Feature selection estimator</td>
#       <td id="T_4364b_row16_col1" class="data row16 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4364b_row17_col0" class="data row17 col0" >Number of features selected</td>
#       <td id="T_4364b_row17_col1" class="data row17 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4364b_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_4364b_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4364b_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_4364b_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4364b_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_4364b_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4364b_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_4364b_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4364b_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_4364b_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_4364b_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_4364b_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4364b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_4364b_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_4364b_row24_col1" class="data row24 col1" >6404</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_57d9b_row10_col0, #T_57d9b_row10_col1, #T_57d9b_row10_col2, #T_57d9b_row10_col3, #T_57d9b_row10_col4, #T_57d9b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_57d9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57d9b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_57d9b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_57d9b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_57d9b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_57d9b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_57d9b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57d9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57d9b_row0_col0" class="data row0 col0" >0.6420</td>
#       <td id="T_57d9b_row0_col1" class="data row0 col1" >0.5213</td>
#       <td id="T_57d9b_row0_col2" class="data row0 col2" >0.7220</td>
#       <td id="T_57d9b_row0_col3" class="data row0 col3" >0.4604</td>
#       <td id="T_57d9b_row0_col4" class="data row0 col4" >0.1220</td>
#       <td id="T_57d9b_row0_col5" class="data row0 col5" >0.1356</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57d9b_row1_col0" class="data row1 col0" >0.5870</td>
#       <td id="T_57d9b_row1_col1" class="data row1 col1" >0.4955</td>
#       <td id="T_57d9b_row1_col2" class="data row1 col2" >0.7039</td>
#       <td id="T_57d9b_row1_col3" class="data row1 col3" >0.4342</td>
#       <td id="T_57d9b_row1_col4" class="data row1 col4" >0.1060</td>
#       <td id="T_57d9b_row1_col5" class="data row1 col5" >0.1018</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57d9b_row2_col0" class="data row2 col0" >0.4805</td>
#       <td id="T_57d9b_row2_col1" class="data row2 col1" >0.2956</td>
#       <td id="T_57d9b_row2_col2" class="data row2 col2" >0.5437</td>
#       <td id="T_57d9b_row2_col3" class="data row2 col3" >0.5096</td>
#       <td id="T_57d9b_row2_col4" class="data row2 col4" >0.0928</td>
#       <td id="T_57d9b_row2_col5" class="data row2 col5" >0.0921</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57d9b_row3_col0" class="data row3 col0" >0.6595</td>
#       <td id="T_57d9b_row3_col1" class="data row3 col1" >0.7413</td>
#       <td id="T_57d9b_row3_col2" class="data row3 col2" >0.8610</td>
#       <td id="T_57d9b_row3_col3" class="data row3 col3" >0.3236</td>
#       <td id="T_57d9b_row3_col4" class="data row3 col4" >0.1271</td>
#       <td id="T_57d9b_row3_col5" class="data row3 col5" >0.1161</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57d9b_row4_col0" class="data row4 col0" >0.7887</td>
#       <td id="T_57d9b_row4_col1" class="data row4 col1" >0.9314</td>
#       <td id="T_57d9b_row4_col2" class="data row4 col2" >0.9651</td>
#       <td id="T_57d9b_row4_col3" class="data row4 col3" >0.0244</td>
#       <td id="T_57d9b_row4_col4" class="data row4 col4" >0.1614</td>
#       <td id="T_57d9b_row4_col5" class="data row4 col5" >0.1693</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_57d9b_row5_col0" class="data row5 col0" >0.5112</td>
#       <td id="T_57d9b_row5_col1" class="data row5 col1" >0.5676</td>
#       <td id="T_57d9b_row5_col2" class="data row5 col2" >0.7534</td>
#       <td id="T_57d9b_row5_col3" class="data row5 col3" >0.3176</td>
#       <td id="T_57d9b_row5_col4" class="data row5 col4" >0.1445</td>
#       <td id="T_57d9b_row5_col5" class="data row5 col5" >0.1058</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_57d9b_row6_col0" class="data row6 col0" >0.7773</td>
#       <td id="T_57d9b_row6_col1" class="data row6 col1" >0.8347</td>
#       <td id="T_57d9b_row6_col2" class="data row6 col2" >0.9136</td>
#       <td id="T_57d9b_row6_col3" class="data row6 col3" >0.5118</td>
#       <td id="T_57d9b_row6_col4" class="data row6 col4" >0.1510</td>
#       <td id="T_57d9b_row6_col5" class="data row6 col5" >0.1612</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_57d9b_row7_col0" class="data row7 col0" >0.7790</td>
#       <td id="T_57d9b_row7_col1" class="data row7 col1" >0.8689</td>
#       <td id="T_57d9b_row7_col2" class="data row7 col2" >0.9322</td>
#       <td id="T_57d9b_row7_col3" class="data row7 col3" >0.6057</td>
#       <td id="T_57d9b_row7_col4" class="data row7 col4" >0.1409</td>
#       <td id="T_57d9b_row7_col5" class="data row7 col5" >0.1437</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_57d9b_row8_col0" class="data row8 col0" >0.5494</td>
#       <td id="T_57d9b_row8_col1" class="data row8 col1" >0.4776</td>
#       <td id="T_57d9b_row8_col2" class="data row8 col2" >0.6911</td>
#       <td id="T_57d9b_row8_col3" class="data row8 col3" >0.4620</td>
#       <td id="T_57d9b_row8_col4" class="data row8 col4" >0.1173</td>
#       <td id="T_57d9b_row8_col5" class="data row8 col5" >0.1154</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_57d9b_row9_col0" class="data row9 col0" >0.6848</td>
#       <td id="T_57d9b_row9_col1" class="data row9 col1" >0.7730</td>
#       <td id="T_57d9b_row9_col2" class="data row9 col2" >0.8792</td>
#       <td id="T_57d9b_row9_col3" class="data row9 col3" >0.2596</td>
#       <td id="T_57d9b_row9_col4" class="data row9 col4" >0.1219</td>
#       <td id="T_57d9b_row9_col5" class="data row9 col5" >0.1103</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_57d9b_row10_col0" class="data row10 col0" >0.6459</td>
#       <td id="T_57d9b_row10_col1" class="data row10 col1" >0.6507</td>
#       <td id="T_57d9b_row10_col2" class="data row10 col2" >0.7965</td>
#       <td id="T_57d9b_row10_col3" class="data row10 col3" >0.3909</td>
#       <td id="T_57d9b_row10_col4" class="data row10 col4" >0.1285</td>
#       <td id="T_57d9b_row10_col5" class="data row10 col5" >0.1251</td>
#     </tr>
#     <tr>
#       <th id="T_57d9b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_57d9b_row11_col0" class="data row11 col0" >0.1074</td>
#       <td id="T_57d9b_row11_col1" class="data row11 col1" >0.1968</td>
#       <td id="T_57d9b_row11_col2" class="data row11 col2" >0.1275</td>
#       <td id="T_57d9b_row11_col3" class="data row11 col3" >0.1575</td>
#       <td id="T_57d9b_row11_col4" class="data row11 col4" >0.0200</td>
#       <td id="T_57d9b_row11_col5" class="data row11 col5" >0.0247</td>
#     </tr>
#   </tbody>
# </table>

# %%
feature_selection: bool, default = False
When set to True, a subset of features is selected based on a feature importance score determined by feature_selection_estimator.
feature_selection_method: str, default = 'classic'
Algorithm for feature selection. Choose from:
'univariate': Uses sklearn's SelectKBest.
'classic': Uses sklearn's SelectFromModel.
'sequential': Uses sklearn's SequentialFeatureSelector.

# %%
# Dash board creation for XAI

# %%
reg_exp1.dashboard(regression1, display_format='dash')
# click on the, Starting ExplainerDashboard on 
# http://10.25.112.104:8050, to get the dashboard

# inline can also be used
#dashboard(regression1, display_format='inline')
# Out:
# WARNING: For shap='linear', shap interaction values can unfortunately not be calculated!
# Warning: shap values for shap.LinearExplainer get calculated against X_background, but paramater X_background=None, so using X instead
# Generating self.shap_explainer = shap.LinearExplainer(modelX)...
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# For this type of model and model_output interactions don't work, so setting shap_interaction=False...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Generating layout...
# Calculating shap values...
# Calculating predictions...
# Calculating residuals...
# Calculating absolute residuals...
# Calculating dependencies...
# Calculating importances...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard on http://192.168.1.5:8050
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# OSError: [WinError 10049] The requested address is not valid in its context
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connectionpool.py:416, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415     else:
# --> 416         conn.request(method, url, **httplib_request_kw)
#     418 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     419 # legitimately able to close the connection after sending a valid response.
#     420 # With this behaviour, the received response is still readable.
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\http\client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\http\client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001C294005400>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='0.0.0.0', port=8050): Max retries exceeded with url: /_alive_beba4879-8064-442c-a598-a49cfa42889b (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001C294005400>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 reg_exp1.dashboard(regression1, display_format='dash')
#       2 # click on the, Starting ExplainerDashboard on
#       3 # http://10.25.112.104:8050, to get the dashboard
#       4
#       5 # inline can also be used
#       6 #dashboard(regression1, display_format='inline')
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\pycaret\regression\oop.py:2791, in RegressionExperiment.dashboard(self, estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#    2784 X_test_df.columns = [
#    2785     col.replace(".", "__").replace("{", "__").replace("}", "__")
#    2786     for col in X_test_df.columns
#    2787 ]
#    2788 explainer = RegressionExplainer(
#    2789     estimator, X_test_df, self.y_test_transformed, **kwargs
#    2790 )
# -> 2791 return ExplainerDashboard(
#    2792     explainer, mode=display_format, **dashboard_kwargs
#    2793 ).run(**run_kwargs)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\explainerdashboard\dashboards.py:1278, in ExplainerDashboard.run(self, port, host, use_waitress, mode, **kwargs)
#    1276         serve(app.server, host=host, port=port)
#    1277     else:
# -> 1278         app.run_server(port=port, host=host, **kwargs)
#    1279 else:
#    1280     if self.mode == "dash":
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\dash\_jupyter.py:388, in JupyterDash.run_app.<locals>.wait_for_app()
#     386 except requests.ConnectionError as err:
#     387     _get_error()
# --> 388     raise err
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\dash\_jupyter.py:375, in JupyterDash.run_app.<locals>.wait_for_app()
#     373 _get_error()
#     374 try:
# --> 375     req = requests.get(alive_url)
#     376     res = req.content.decode()
#     377     if req.status_code != 200:
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File C:\ProgramData\Anaconda3\envs\pycaretenv\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='0.0.0.0', port=8050): Max retries exceeded with url: /_alive_beba4879-8064-442c-a598-a49cfa42889b (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001C294005400>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context'))
