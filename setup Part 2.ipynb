# %%
# start with pandas and numpy

# %%
import pandas as pd
import numpy as np

# %%
# import the data set
data1 =  pd.read_csv("C:\\Users\\Manohar Kapse\\PyCaret\\happyness_scale.csv")

# %%
data1.head()
# Out:
#     Country  SNO  Happyness_Score    GDP  Social_support  \
# 0  country1    1            7.769  1.340           1.587
# 1  country2    2            7.600  1.383           1.573
# 2  country3    3            7.554  1.488           1.582
# 3  country4    4            7.494  1.380           1.624
# 4  country5    5            7.488  1.396           1.522
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions_of_corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
from pycaret import *

# %%
### https://pycaret.gitbook.io/docs/

# %%
from pycaret.regression import *

# %%
# start regression with 
# RegressionExperiment
reg_exp = RegressionExperiment()

# %%
# Basic setup
# Step 1
reg_exp1 = reg_exp.setup(data=data1, target="Happyness_Score")
# Out:
# <style type="text/css">
# #T_1b56a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1b56a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b56a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1b56a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b56a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b56a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1b56a_row0_col1" class="data row0 col1" >3778</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b56a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1b56a_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b56a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1b56a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b56a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1b56a_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b56a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1b56a_row4_col1" class="data row4 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b56a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1b56a_row5_col1" class="data row5 col1" >(109, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b56a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1b56a_row6_col1" class="data row6 col1" >(47, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b56a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1b56a_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b56a_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_1b56a_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1b56a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_1b56a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1b56a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_1b56a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1b56a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_1b56a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1b56a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_1b56a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1b56a_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_1b56a_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1b56a_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_1b56a_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1b56a_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1b56a_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1b56a_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1b56a_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1b56a_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1b56a_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1b56a_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1b56a_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1b56a_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1b56a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1b56a_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1b56a_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1b56a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1b56a_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1b56a_row21_col1" class="data row21 col1" >cd7b</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Add type of variables in setup, numeric, categorical and ordinal
#1. ignore_features, is also used for removing the variables 
#Such as name, sno etc None
#2. numeric_features: list of string, default = None
#3. categorical_features: list of string, default = None

# %%
# step 2
reg_exp1=reg_exp.setup(data=data1, target="Happyness_Score", 
      ignore_features=["Country", "SNO"])
# Out:
# <style type="text/css">
# #T_21a46_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_21a46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21a46_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_21a46_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21a46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21a46_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_21a46_row0_col1" class="data row0 col1" >8396</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21a46_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_21a46_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21a46_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_21a46_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21a46_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_21a46_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21a46_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_21a46_row4_col1" class="data row4 col1" >(156, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21a46_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_21a46_row5_col1" class="data row5 col1" >(109, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21a46_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_21a46_row6_col1" class="data row6 col1" >(47, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_21a46_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_21a46_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_21a46_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_21a46_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_21a46_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_21a46_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_21a46_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_21a46_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_21a46_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_21a46_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_21a46_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_21a46_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_21a46_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_21a46_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_21a46_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_21a46_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_21a46_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_21a46_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_21a46_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_21a46_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_21a46_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_21a46_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_21a46_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_21a46_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_21a46_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_21a46_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_21a46_row19_col1" class="data row19 col1" >c591</td>
#     </tr>
#   </tbody>
# </table>

# %%
# step 3
# want to inform the system about the variables information 
# such as numeric, ordinal and categorical
reg_exp1= reg_exp.setup(data=data1, target="Happyness_Score", 
                              numeric_features=["GDP",
                                                "Social_support", 
                                                "Healthy_life_expectancy",  
                                                "Freedom_to_make_life_choices", 
                                                "Generosity",  
                                                "Perceptions_of_corruption"], 
                             ignore_features=["Country", "SNO"])
# Out:
# <style type="text/css">
# #T_3e3d5_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3e3d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e3d5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3e3d5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e3d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e3d5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3e3d5_row0_col1" class="data row0 col1" >1399</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e3d5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3e3d5_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e3d5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3e3d5_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e3d5_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3e3d5_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e3d5_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3e3d5_row4_col1" class="data row4 col1" >(156, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3e3d5_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3e3d5_row5_col1" class="data row5 col1" >(109, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3e3d5_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3e3d5_row6_col1" class="data row6 col1" >(47, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3e3d5_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_3e3d5_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3e3d5_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_3e3d5_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3e3d5_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_3e3d5_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3e3d5_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_3e3d5_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3e3d5_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_3e3d5_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3e3d5_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_3e3d5_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3e3d5_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_3e3d5_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3e3d5_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_3e3d5_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3e3d5_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_3e3d5_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3e3d5_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_3e3d5_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3e3d5_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_3e3d5_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3e3d5_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_3e3d5_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3e3d5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3e3d5_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_3e3d5_row19_col1" class="data row19 col1" >9444</td>
#     </tr>
#   </tbody>
# </table>

# %%
# step 3
# want to inform the system about the variables
# such as numeric, ordinal and categorical
reg_exp1= reg_exp.setup(data=data1, target="Happyness_Score", 
                              numeric_features=["GDP",
                                                "Social_support", 
                                                "Healthy_life_expectancy",  
                                                "Freedom_to_make_life_choices", 
                                                "Generosity",  
                                                "Perceptions_of_corruption"],
      categorical_features=["Country"],
      ignore_features=["SNO"])
# Out:
# <style type="text/css">
# #T_d665c_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d665c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d665c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d665c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d665c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d665c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d665c_row0_col1" class="data row0 col1" >1797</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d665c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d665c_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d665c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d665c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d665c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d665c_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d665c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d665c_row4_col1" class="data row4 col1" >(156, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d665c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d665c_row5_col1" class="data row5 col1" >(109, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d665c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d665c_row6_col1" class="data row6 col1" >(47, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d665c_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_d665c_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d665c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d665c_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d665c_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_d665c_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d665c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_d665c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d665c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_d665c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d665c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_d665c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d665c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_d665c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d665c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_d665c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d665c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_d665c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d665c_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_d665c_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d665c_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_d665c_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d665c_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_d665c_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d665c_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_d665c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d665c_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_d665c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d665c_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_d665c_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d665c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d665c_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_d665c_row22_col1" class="data row22 col1" >d90e</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Preprocess 
# preprocess = True, 
When set to False, no transformations are applied except for train_test_split 
and custom transformations passed in custom_pipeline param.

# %%
#How to pre process data
1.missing value
# imputation type: simple, none and iterative
A. remove missing or B. impute them.
    to remove missing use drop in imputation
1. numeric imputation
    drop: Drop rows containing missing values. 
    mean: Impute with mean of column. 
    median: Impute with median of column.
    mode: Impute with most frequent value.
    knn: Impute using a K-Nearest Neighbors approach. 
    int or float: Impute with provided numerical value.

# %%
reg_exp1 = reg_exp1.setup(data=data1, target="Happyness_Score",
numeric_imputation="mean")
# Out:
# <style type="text/css">
# #T_611c1_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_611c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_611c1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_611c1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_611c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_611c1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_611c1_row0_col1" class="data row0 col1" >3685</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_611c1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_611c1_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_611c1_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_611c1_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_611c1_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_611c1_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_611c1_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_611c1_row4_col1" class="data row4 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_611c1_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_611c1_row5_col1" class="data row5 col1" >(109, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_611c1_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_611c1_row6_col1" class="data row6 col1" >(47, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_611c1_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_611c1_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_611c1_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_611c1_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_611c1_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_611c1_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_611c1_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_611c1_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_611c1_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_611c1_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_611c1_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_611c1_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_611c1_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_611c1_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_611c1_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_611c1_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_611c1_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_611c1_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_611c1_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_611c1_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_611c1_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_611c1_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_611c1_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_611c1_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_611c1_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_611c1_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_611c1_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_611c1_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_611c1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_611c1_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_611c1_row21_col1" class="data row21 col1" >9dd3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2. categorical imputation
# drop: Drop rows containing missing values.
# mode: Impute with most frequent value.
# str: Impute with provided string.

# %%
reg_exp1 = reg_exp.setup(data=data1, target="Happyness_Score",
categorical_imputation="mode")
# Out:
# <style type="text/css">
# #T_9f585_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9f585">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f585_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9f585_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f585_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f585_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9f585_row0_col1" class="data row0 col1" >619</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f585_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9f585_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f585_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9f585_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f585_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9f585_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f585_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9f585_row4_col1" class="data row4 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f585_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9f585_row5_col1" class="data row5 col1" >(109, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9f585_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9f585_row6_col1" class="data row6 col1" >(47, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9f585_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9f585_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9f585_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_9f585_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9f585_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_9f585_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9f585_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_9f585_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9f585_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_9f585_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9f585_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_9f585_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9f585_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_9f585_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9f585_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_9f585_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9f585_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_9f585_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9f585_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_9f585_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9f585_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_9f585_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9f585_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_9f585_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9f585_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_9f585_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9f585_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_9f585_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9f585_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9f585_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_9f585_row21_col1" class="data row21 col1" >efab</td>
#     </tr>
#   </tbody>
# </table>

# %%
reg_exp1=reg_exp.setup(data=data1, target="Happyness_Score", imputation_type='simple')
# Out:
# <style type="text/css">
# #T_5043c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5043c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5043c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5043c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5043c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5043c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5043c_row0_col1" class="data row0 col1" >753</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5043c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5043c_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5043c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5043c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5043c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5043c_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5043c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5043c_row4_col1" class="data row4 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5043c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5043c_row5_col1" class="data row5 col1" >(109, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5043c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5043c_row6_col1" class="data row6 col1" >(47, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5043c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5043c_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5043c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_5043c_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5043c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_5043c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5043c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_5043c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5043c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_5043c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5043c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_5043c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5043c_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_5043c_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5043c_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_5043c_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5043c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_5043c_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5043c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_5043c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5043c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_5043c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5043c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_5043c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5043c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_5043c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5043c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_5043c_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5043c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5043c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_5043c_row21_col1" class="data row21 col1" >7223</td>
#     </tr>
#   </tbody>
# </table>

# %%
2.outliers detection

remove_outliers: bool = False,
    outliers_method: str = 'iforest',
    outliers_threshold: float = 0.05,
        
'iforest': Uses sklearn's IsolationForest.
'ee': Uses sklearn's EllipticEnvelope.
'lof': Uses sklearn's LocalOutlierFactor.

# %%
3.Scale-normalize
normalize: bool = False,
normalize_method: str = 'zscore',
      
z-score
The standard zscore is calculated as z = (x – u) / s
minmax
scales and translates each feature individually such that it is in the
range of 0 – 1.
maxabs
scales and translates each feature individually such that the
maximal absolute value of each feature will be 1.0. 
It does not shift/center the data and thus does not destroy any sparsity.
robust
scales and translates each feature according to the Interquartile range. 
When the dataset contains outliers, the robust scaler often gives
better results.

# %%
# Transformation of variable, features or target

# %%
# for scale data
transformation = False,True
transformation_method: str = 'yeo-johnson'or 'quantile'

    
transform_target: bool = False,
transform_target_method: str = 'yeo-johnson' or  'quantile' 
    they transform the variables to normal

# %%
fold_strategy: Union[str, Any] = 'kfold',
    fold: int = 10,

# %%
# experiment_regression = setup(data=data1, target="Happyness_Score",
                             train_size= 0.8)

# %%
# second Part of the video

# %%
feature_selection: bool = False,
    feature_selection_method: str = 'classic',
    feature_selection_estimator: Union[str, Any] = 'lightgbm',
    n_features_to_select: Union[int, float] = 0.2,
    
low_variance_threshold: Optional[float] = None,

# %%
Target imbalance
fix_imbalance = True, SMOTE (Synthetic Minority Over-sampling Technique)is default
fix_imbalance_method= other methods can be dealth later
Example: 
from imblearn.over_sampling import *
adasyn1 = ADASYN(sampling_strategy='minority')

# %% [markdown]
# test and train data set split
# train_size: float = 0.7

# %% [markdown]
# inorder to get information regarding the global variables use
# get_config()

# %%
# get_config()
x1 = get_config('X')
y1 = get_config('y')

# %%
#x1, y1

# %% [markdown]
# This function is used to reset global environment variables.
# set_config()

# %%
set_config('seed', 123)

# %%
# create a specific model, say linear regression
regression1 = reg_exp.create_model('lr')
# Out:
# <style type="text/css">
# #T_0c84b_row10_col0, #T_0c84b_row10_col1, #T_0c84b_row10_col2, #T_0c84b_row10_col3, #T_0c84b_row10_col4, #T_0c84b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0c84b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c84b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0c84b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0c84b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0c84b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0c84b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0c84b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c84b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c84b_row0_col0" class="data row0 col0" >0.8072</td>
#       <td id="T_0c84b_row0_col1" class="data row0 col1" >0.9765</td>
#       <td id="T_0c84b_row0_col2" class="data row0 col2" >0.9882</td>
#       <td id="T_0c84b_row0_col3" class="data row0 col3" >-0.0081</td>
#       <td id="T_0c84b_row0_col4" class="data row0 col4" >0.1487</td>
#       <td id="T_0c84b_row0_col5" class="data row0 col5" >0.1465</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c84b_row1_col0" class="data row1 col0" >0.9502</td>
#       <td id="T_0c84b_row1_col1" class="data row1 col1" >1.0830</td>
#       <td id="T_0c84b_row1_col2" class="data row1 col2" >1.0407</td>
#       <td id="T_0c84b_row1_col3" class="data row1 col3" >-0.0128</td>
#       <td id="T_0c84b_row1_col4" class="data row1 col4" >0.1732</td>
#       <td id="T_0c84b_row1_col5" class="data row1 col5" >0.1958</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c84b_row2_col0" class="data row2 col0" >1.0631</td>
#       <td id="T_0c84b_row2_col1" class="data row2 col1" >1.7541</td>
#       <td id="T_0c84b_row2_col2" class="data row2 col2" >1.3244</td>
#       <td id="T_0c84b_row2_col3" class="data row2 col3" >-0.2106</td>
#       <td id="T_0c84b_row2_col4" class="data row2 col4" >0.2470</td>
#       <td id="T_0c84b_row2_col5" class="data row2 col5" >0.2807</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c84b_row3_col0" class="data row3 col0" >1.1737</td>
#       <td id="T_0c84b_row3_col1" class="data row3 col1" >1.7649</td>
#       <td id="T_0c84b_row3_col2" class="data row3 col2" >1.3285</td>
#       <td id="T_0c84b_row3_col3" class="data row3 col3" >-0.0446</td>
#       <td id="T_0c84b_row3_col4" class="data row3 col4" >0.1940</td>
#       <td id="T_0c84b_row3_col5" class="data row3 col5" >0.2035</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c84b_row4_col0" class="data row4 col0" >0.7931</td>
#       <td id="T_0c84b_row4_col1" class="data row4 col1" >0.9621</td>
#       <td id="T_0c84b_row4_col2" class="data row4 col2" >0.9809</td>
#       <td id="T_0c84b_row4_col3" class="data row4 col3" >-0.1098</td>
#       <td id="T_0c84b_row4_col4" class="data row4 col4" >0.1537</td>
#       <td id="T_0c84b_row4_col5" class="data row4 col5" >0.1469</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c84b_row5_col0" class="data row5 col0" >0.9758</td>
#       <td id="T_0c84b_row5_col1" class="data row5 col1" >1.4589</td>
#       <td id="T_0c84b_row5_col2" class="data row5 col2" >1.2079</td>
#       <td id="T_0c84b_row5_col3" class="data row5 col3" >-0.0011</td>
#       <td id="T_0c84b_row5_col4" class="data row5 col4" >0.1949</td>
#       <td id="T_0c84b_row5_col5" class="data row5 col5" >0.1983</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c84b_row6_col0" class="data row6 col0" >1.1142</td>
#       <td id="T_0c84b_row6_col1" class="data row6 col1" >1.7071</td>
#       <td id="T_0c84b_row6_col2" class="data row6 col2" >1.3066</td>
#       <td id="T_0c84b_row6_col3" class="data row6 col3" >-0.3487</td>
#       <td id="T_0c84b_row6_col4" class="data row6 col4" >0.2306</td>
#       <td id="T_0c84b_row6_col5" class="data row6 col5" >0.2692</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c84b_row7_col0" class="data row7 col0" >0.6316</td>
#       <td id="T_0c84b_row7_col1" class="data row7 col1" >0.6463</td>
#       <td id="T_0c84b_row7_col2" class="data row7 col2" >0.8039</td>
#       <td id="T_0c84b_row7_col3" class="data row7 col3" >-0.1206</td>
#       <td id="T_0c84b_row7_col4" class="data row7 col4" >0.1209</td>
#       <td id="T_0c84b_row7_col5" class="data row7 col5" >0.1116</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c84b_row8_col0" class="data row8 col0" >0.7181</td>
#       <td id="T_0c84b_row8_col1" class="data row8 col1" >0.7362</td>
#       <td id="T_0c84b_row8_col2" class="data row8 col2" >0.8580</td>
#       <td id="T_0c84b_row8_col3" class="data row8 col3" >-0.3057</td>
#       <td id="T_0c84b_row8_col4" class="data row8 col4" >0.1265</td>
#       <td id="T_0c84b_row8_col5" class="data row8 col5" >0.1205</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c84b_row9_col0" class="data row9 col0" >1.0269</td>
#       <td id="T_0c84b_row9_col1" class="data row9 col1" >1.4967</td>
#       <td id="T_0c84b_row9_col2" class="data row9 col2" >1.2234</td>
#       <td id="T_0c84b_row9_col3" class="data row9 col3" >-0.0004</td>
#       <td id="T_0c84b_row9_col4" class="data row9 col4" >0.1937</td>
#       <td id="T_0c84b_row9_col5" class="data row9 col5" >0.2016</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0c84b_row10_col0" class="data row10 col0" >0.9254</td>
#       <td id="T_0c84b_row10_col1" class="data row10 col1" >1.2586</td>
#       <td id="T_0c84b_row10_col2" class="data row10 col2" >1.1062</td>
#       <td id="T_0c84b_row10_col3" class="data row10 col3" >-0.1162</td>
#       <td id="T_0c84b_row10_col4" class="data row10 col4" >0.1783</td>
#       <td id="T_0c84b_row10_col5" class="data row10 col5" >0.1874</td>
#     </tr>
#     <tr>
#       <th id="T_0c84b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0c84b_row11_col0" class="data row11 col0" >0.1704</td>
#       <td id="T_0c84b_row11_col1" class="data row11 col1" >0.4057</td>
#       <td id="T_0c84b_row11_col2" class="data row11 col2" >0.1866</td>
#       <td id="T_0c84b_row11_col3" class="data row11 col3" >0.1237</td>
#       <td id="T_0c84b_row11_col4" class="data row11 col4" >0.0396</td>
#       <td id="T_0c84b_row11_col5" class="data row11 col5" >0.0544</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Study the output of the model
regression1.coef_
# Out:
# array([ 7.68589444e+00,  1.42694171e-17, -2.30887429e-15,  1.26027227e-15,
#         3.62640991e-15,  1.62352998e-15, -4.73245450e-15,  5.22414648e-15])

# %%
# multicollinearity

experiment_regression = setup(data=data1, target="Happyness_Score", 
                              numeric_features=["GDP",
                                                "Social_support", 
                                                "Healthy_life_expectancy",  
                                                "Freedom_to_make_life_choices", 
                                                "Generosity",  
                                                "Perceptions_of_corruption"], 
                             ignore_features=["Country", "SNO"], 
                             remove_multicollinearity=True)
# Out:
# <style type="text/css">
# #T_371cf_row9_col1, #T_371cf_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_371cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_371cf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_371cf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_371cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_371cf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_371cf_row0_col1" class="data row0 col1" >2410</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_371cf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_371cf_row1_col1" class="data row1 col1" >Happyness_Score</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_371cf_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_371cf_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_371cf_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_371cf_row3_col1" class="data row3 col1" >(156, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_371cf_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_371cf_row4_col1" class="data row4 col1" >(156, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_371cf_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_371cf_row5_col1" class="data row5 col1" >(109, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_371cf_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_371cf_row6_col1" class="data row6 col1" >(47, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_371cf_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_371cf_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_371cf_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_371cf_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_371cf_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_371cf_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_371cf_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_371cf_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_371cf_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_371cf_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_371cf_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_371cf_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_371cf_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_371cf_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_371cf_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_371cf_row14_col1" class="data row14 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_371cf_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_371cf_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_371cf_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_371cf_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_371cf_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_371cf_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_371cf_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_371cf_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_371cf_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_371cf_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_371cf_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_371cf_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_371cf_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_371cf_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_371cf_row21_col1" class="data row21 col1" >5479</td>
#     </tr>
#   </tbody>
# </table>

# %%
regression2 = experiment_regression.create_model('lr')

# %%
evaluate_model(regression2)

# %%
evaluate_model(regression1)

# %%
# we can use any data for prediction, from 
#predict_model(regression1)
#predict_model(regression1, data=data1)

# %%
dashboard(regression1, display_format='dash')
# click on the, Starting ExplainerDashboard on 
# http://10.25.112.104:8050, to get the dashboard

# inline can also be used
#dashboard(regression1, display_format='inline')
